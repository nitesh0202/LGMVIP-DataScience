# %% [markdown]
# # LETS GROW MORE DATA SCIENCE INTERNSHIP(VIP)

# %% [markdown]
# ## Name: Nitesh Kumar Mahto

# %% [markdown]
# ## Task 2: Prediction Using Decision Tree Algorithm

# %%
#Imorting Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
X = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values
X[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
Y= data['Species']
Y[0:5]
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#spliting data into trainset and testset
from sklearn.model_selection import train_test_split
x=data.iloc[:,:3]
y=data["Species"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=8)

# %%
#Visualize the decision tree
from sklearn import tree
decision_tree=tree.DecisionTreeClassifier()
decision_tree.fit(x_train,y_train)
predictedTree=decision_tree.predict(x_test)

figure=plt.figure(figsize=(12,15))
_ = tree.plot_tree(decision_tree, 
                   feature_names=['sepal_length', 'sepal_width', 'petal_length','petal_width'],  
                   class_names=['Setosa', 'Versicolor', 'Virginica'],
                   filled=True)

# %%
from sklearn import metrics
print("Accuracy of decision tree :",metrics.accuracy_score(y_test, predictedTree) )
# Out:
# Accuracy of decision tree : 1.0

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
print(X_train)
# Out:
# [[ 0.9902527   0.78130064 -0.11914077]
#  [ 0.45524387 -0.32663619 -0.80649139]
#  [-0.05544637  0.28888427 -0.57737451]
#  [-1.05250827 -0.81905256  2.40114481]
#  [-1.68479142 -1.55767711  0.79732671]
#  [-0.71204811 -0.94215665  1.71379419]
#  [-0.88227819 -0.94215665  0.79732671]
#  [-0.51749944  0.78130064 -0.57737451]
#  [ 1.62253585 -0.08042801 -0.80649139]
#  [ 0.16342088 -0.08042801 -0.80649139]
#  [ 1.03888986  2.25854974 -1.03560826]
#  [-0.93091535 -1.18836484  0.1099761 ]
#  [ 1.23343852  0.41198836 -0.57737451]
#  [ 1.57389869  1.02750882  0.1099761 ]
#  [-0.95523394 -0.44974028  1.02644358]
#  [ 1.16048278  0.53509245 -0.80649139]
#  [-0.90659677 -1.8038853  -0.11914077]
#  [-1.78206576 -1.43457302  0.33909297]
#  [ 0.67411112  0.53509245 -0.34825764]
#  [-1.66047284 -1.06526074  0.79732671]
#  [-0.27431362 -0.32663619 -0.34825764]
#  [-1.58751709 -0.57284438  1.48467732]
#  [-0.68772952 -1.55767711  0.33909297]
#  [ 0.47956245 -0.2035321  -0.11914077]
# ...

# %%
print(X_test)
# Out:
# [[-1.73342859 -1.06526074  1.25556045]
#  [-1.12546402 -1.43457302  0.33909297]
#  [-1.17410118 -0.81905256  1.02644358]
#  [ 1.59821727  1.27371701  0.1099761 ]
#  [-0.24999503  1.02750882  0.1099761 ]
#  [-1.0038711  -1.18836484  0.1099761 ]
#  [-1.27137551 -0.94215665  0.56820984]
#  [ 1.6954916   1.02750882 -0.11914077]
#  [ 1.37935002  0.65819655 -0.57737451]
#  [-0.03112779  0.65819655 -0.34825764]
#  [-0.46886228  0.53509245  0.56820984]
#  [-1.10114543 -1.31146893  0.1099761 ]
#  [ 0.74706687 -1.18836484 -1.26472513]
#  [-0.61477378  1.3968211   0.33909297]
#  [ 1.06320844  0.16578018 -1.95207574]
#  [ 1.71981018  0.53509245 -1.26472513]
#  [ 1.50094294  0.65819655  0.1099761 ]
#  [ 1.25775711  0.28888427 -0.11914077]
#  [-0.12840212  0.04267609  0.33909297]
#  [ 1.30639427  1.64302928 -0.11914077]
#  [-0.56613661  1.27371701  0.1099761 ]
#  [-1.80638434 -1.18836484 -0.11914077]
#  [-0.20135787 -0.08042801 -0.80649139]
#  [ 0.33365096 -0.44974028 -1.26472513]
# ...

# %%
sns.pairplot(data=data, hue='Species')
plt.show()
